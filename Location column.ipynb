# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt

# %%
df = pd.read_excel('cleaned.xlsx')
df.head(5)
# Out:
#                                             position             company  \
# 0                               development director             als tdi
# 1  an ostentatiously-excitable principal research...  the hexagon lavish
# 2                                     data scientist      xpert staffing
# 3                                       data analyst      operation hope
# 4  assistant professor -tt - signal processing & ...    emory university
#
#                                          description            location
# 0  development director\nals therapy development ...  atlanta, ga 30301
# 1  job description\n\n"the road that leads to acc...         atlanta, ga
# 2  growing company located in the atlanta, ga are...         atlanta, ga
# 3  department: program operationsposition locatio...  atlanta, ga 30303
# 4  description\nthe emory university department o...         atlanta, ga

# %%
df.shape
# Out:
# (6953, 4)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6953 entries, 0 to 6952
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   position     6953 non-null   object
#  1   company      6953 non-null   object
#  2   description  6953 non-null   object
#  3   location     6953 non-null   object
# dtypes: object(4)
# memory usage: 217.4+ KB

# %%
df['location']
# Out:
# 0        atlanta, ga 30301
# 1               atlanta, ga
# 2               atlanta, ga
# 3        atlanta, ga 30303
# 4               atlanta, ga
#                ...
# 6948          sunnyvale, ca
# 6949          sunnyvale, ca
# 6950          sunnyvale, ca
# 6951          sunnyvale, ca
# 6952    sunnyvale, ca 94089
# Name: location, Length: 6953, dtype: object

# %%
df[['location']]
# Out:
#                  location
# 0      atlanta, ga 30301
# 1             atlanta, ga
# 2             atlanta, ga
# 3      atlanta, ga 30303
# 4             atlanta, ga
# ...                   ...
# 6948        sunnyvale, ca
# 6949        sunnyvale, ca
# 6950        sunnyvale, ca
# 6951        sunnyvale, ca
# 6952  sunnyvale, ca 94089
#
# [6953 rows x 1 columns]

# %%
df2 = pd.read_excel('cleaned2.xlsx')

# %%
df2
# Out:
#               Unnamed: 0           Unnamed: 1
# 0                    NaN                  NaN
# 1   Zeilenbeschriftungen  Anzahl von location
# 2                alameda                   10
# 3              allendale                    2
# 4                atlanta                  269
# ..                   ...                  ...
# 91        woodcliff lake                    1
# 92               yonkers                    1
# 93                #WERT!                    9
# 94                (Leer)                  NaN
# 95        Gesamtergebnis                 6963
#
# [96 rows x 2 columns]

# %%
df2.head(100)
# Out:
#               Unnamed: 0           Unnamed: 1
# 0                    NaN                  NaN
# 1   Zeilenbeschriftungen  Anzahl von location
# 2                alameda                   10
# 3              allendale                    2
# 4                atlanta                  269
# ..                   ...                  ...
# 91        woodcliff lake                    1
# 92               yonkers                    1
# 93                #WERT!                    9
# 94                (Leer)                  NaN
# 95        Gesamtergebnis                 6963
#
# [96 rows x 2 columns]

# %%
df2 = df2.rename(columns={ 'controln':'id','hv1':'median_home_val', 'ic1':'median_household_income'})

# %%
df3 = pd.read_excel('clean3_pivot.xlsx')
df3.head(100)
# Out:
#    Zeilenbeschriftungen  Anzahl von location
# 0               alameda                 10.0
# 1             allendale                  2.0
# 2               atlanta                269.0
# 3                austin                213.0
# 4            bedminster                  1.0
# ..                  ...                  ...
# 89       woodcliff lake                  1.0
# 90              yonkers                  1.0
# 91               #WERT!                  9.0
# 92               (Leer)                  NaN
# 93       Gesamtergebnis               6963.0
#
# [94 rows x 2 columns]

# %%
df3 = df3.rename(columns={ 'Zeilenbeschriftungen':'location','Anzahl von location':'numbers_of_location_mentioned'})
df3
# Out:
#           location  numbers_of_location_mentioned
# 0          alameda                           10.0
# 1        allendale                            2.0
# 2          atlanta                          269.0
# 3           austin                          213.0
# 4       bedminster                            1.0
# ..             ...                            ...
# 89  woodcliff lake                            1.0
# 90         yonkers                            1.0
# 91          #WERT!                            9.0
# 92          (Leer)                            NaN
# 93  Gesamtergebnis                         6963.0
#
# [94 rows x 2 columns]

# %%
df3.head(100)
# Out:
#           location  numbers_of_location_mentioned
# 0          alameda                           10.0
# 1        allendale                            2.0
# 2          atlanta                          269.0
# 3           austin                          213.0
# 4       bedminster                            1.0
# ..             ...                            ...
# 89  woodcliff lake                            1.0
# 90         yonkers                            1.0
# 91          #WERT!                            9.0
# 92          (Leer)                            NaN
# 93  Gesamtergebnis                         6963.0
#
# [94 rows x 2 columns]

# %%
# df3 = df3[df.duplicated(subset=['number_of_location_mentioned'], keep=False)]
# df3 = df3.drop_duplicates(subset = 'numbers_of_location_mentioned')

#bdf3=df3.drop_duplicates(subset='number_of_location_mentioned', inplace=True)
#df3 = df3.astype(dtype)
#tempdata['avggift'] = data['avggift'].astype('int')


#df3 = result[~(result['Value'] <= 10)]  
#df3


df3['numbers_of_location_mentioned'] =  pd.to_numeric(df3['numbers_of_location_mentioned'], errors='coerce')
df3

# tempdata['median_home_val'] =  pd.to_numeric(tempdata['median_home_val'], errors='coerce')
# Out:
#           location  numbers_of_location_mentioned
# 0          alameda                           10.0
# 1        allendale                            2.0
# 2          atlanta                          269.0
# 3           austin                          213.0
# 4       bedminster                            1.0
# ..             ...                            ...
# 89  woodcliff lake                            1.0
# 90         yonkers                            1.0
# 91          #WERT!                            9.0
# 92          (Leer)                            NaN
# 93  Gesamtergebnis                         6963.0
#
# [94 rows x 2 columns]

# %%
# Tony: drop the last row with the Gesamtergebnis(Total Results)
#test
#df_dropped_last_n = df3.iloc[:-1]
#df_dropped_last_n

df3 = df3.iloc[:-1]
df3
# Out:
#           location  numbers_of_location_mentioned
# 0          alameda                           10.0
# 1        allendale                            2.0
# 2          atlanta                          269.0
# 3           austin                          213.0
# 4       bedminster                            1.0
# ..             ...                            ...
# 88        whippany                            1.0
# 89  woodcliff lake                            1.0
# 90         yonkers                            1.0
# 91          #WERT!                            9.0
# 92          (Leer)                            NaN
#
# [93 rows x 2 columns]

# %%
# Tony: don't think we need the (Leer) and #WERT! group, so I am going to drop that column as well
#removing (Leer)
df3 = df3.iloc[:-1]
df3
# Out:
#           location  numbers_of_location_mentioned
# 0          alameda                           10.0
# 1        allendale                            2.0
# 2          atlanta                          269.0
# 3           austin                          213.0
# 4       bedminster                            1.0
# ..             ...                            ...
# 87     west orange                            1.0
# 88        whippany                            1.0
# 89  woodcliff lake                            1.0
# 90         yonkers                            1.0
# 91          #WERT!                            9.0
#
# [92 rows x 2 columns]

# %%
# removing #WERT! column
df3 = df3.iloc[:-1]
df3
# Out:
#           location  numbers_of_location_mentioned
# 0          alameda                           10.0
# 1        allendale                            2.0
# 2          atlanta                          269.0
# 3           austin                          213.0
# 4       bedminster                            1.0
# ..             ...                            ...
# 86      washington                          340.0
# 87     west orange                            1.0
# 88        whippany                            1.0
# 89  woodcliff lake                            1.0
# 90         yonkers                            1.0
#
# [91 rows x 2 columns]

# %%
df3['numbers_of_location_mentioned'].dtype
# Out:
# dtype('float64')

# %%
df4 = df3[df3['numbers_of_location_mentioned'] > 100]  
df4
# Out:
#          location  numbers_of_location_mentioned
# 2         atlanta                          269.0
# 3          austin                          213.0
# 8          boston                          629.0
# 9         boulder                          251.0
# 13      cambridge                          694.0
# 16        chicago                          471.0
# 35    los angeles                          254.0
# 44  mountain view                          277.0
# 48       new york                          848.0
# 59        redmond                          158.0
# 68      san diego                          412.0
# 69  san francisco                          564.0
# 75        seattle                          777.0
# 81      sunnyvale                          257.0
# 86     washington                          340.0

# %%
df4.to_excel('df_location_column.xlsx')

# %%
df4.shape
# Out:
# (15, 2)

# %%
df4.plot(x='location', y='numbers_of_location_mentioned', kind = 'bar', figsize=(14,10))
plt.show


# Tony: seems like they seeking for lots of data analysts/scientists in Boston, Cambridge, New York, and Seattle
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
